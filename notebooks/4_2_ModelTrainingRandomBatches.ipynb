# %% [markdown]
# ## Load the tokenizer

# %%
import sys
sys.path.append('..')

# %%
from minbpe import BasicTokenizer

tokenizer = BasicTokenizer()
tokenizer.load(model_file="../output/tokenizer/my_tokenizer.model")


def get_vocab_size(tokenizer: BasicTokenizer) -> int:
    vocab = tokenizer.vocab
    special_tokens = tokenizer.special_tokens

    return len(vocab) + len(special_tokens)

# %% [markdown]
# ## Create the model

# %%
import torch
torch.manual_seed(3647)

# %%
from transformer.model import GPTLanguageModel

block_size = 512
n_embd = 128
n_head = 8
n_layer = 1
dropout = 0.2
batch_size = 128
vocab_size = get_vocab_size(tokenizer)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = GPTLanguageModel(
    vocab_size=vocab_size,
    block_size=block_size,
    n_embd=n_embd,
    n_head=n_head,
    n_layer=n_layer,
    dropout=dropout,
    device=device
).to(device)
# model = torch.compile(model)  # Disabled on Windows unless the MSVC C++ compiler is installed

print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 12
#       8 batch_size = 64
#       9 vocab_size = get_vocab_size(tokenizer)
#      10 device = 'cuda' if torch.cuda.is_available() else 'cpu'
#      11
# ---> 12 model = GPTLanguageModel(
#      13     vocab_size=vocab_size,
#      14     block_size=block_size,
#      15     n_embd=n_embd,
#
# File d:\Train_Your_Language_Model_Course-clean\notebooks\..\transformer\model.py:112, in GPTLanguageModel.__init__(self, vocab_size, n_embd, n_head, block_size, n_layer, dropout, device, ignore_index)
#     109 self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
#     110 self.position_embedding_table = nn.Embedding(block_size, n_embd)
#     111 self.blocks = nn.Sequential(*[
# --> 112     Block(n_embd, n_head, block_size, dropout)
#     113     for _ in range(n_layer)
#     114 ])
#     115 self.final_layer_norm = nn.LayerNorm(n_embd)
#     116 self.final_linear_layer = nn.Linear(n_embd, vocab_size)
#
# File d:\Train_Your_Language_Model_Course-clean\notebooks\..\transformer\model.py:74, in Block.__init__(self, n_embd, n_head, block_size, dropout)
#      72 head_size = n_embd // n_head
#      73 error_message = f"n_embd {n_embd} must be divisible by n_head {n_head}"
# ---> 74 assert head_size * n_head == n_embd, error_message
#      75 self.self_attention = MultiHeadAttention(
#      76     n_embd=n_embd,
#      77     num_heads=n_head,
#    (...)     80     dropout=dropout
#      81 )
#      82 self.feed_forward = FeedForward(n_embd, dropout)
#
# AssertionError: n_embd 512 must be divisible by n_head 12

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### 1. Load the data

# %%
with open("../output/combined_text.txt", "r") as f:
    with open("../output/combined_text.txt", "r", encoding="utf-8") as f:
        text_sequence = f.read()

encoded_text_sequence = tokenizer.encode(text_sequence)
len(encoded_text_sequence)
# Out:
# 411925

# %% [markdown]
# ### 2. Split it into train and test

# %%
data = torch.tensor(encoded_text_sequence, dtype=torch.long)
split_index = int(0.9*len(data))
train_data = data[:split_index]
val_data = data[split_index:]

# %% [markdown]
# ### 3. Data loader

# %%
from typing import Tuple


def get_batch(split: str) -> Tuple[torch.Tensor, torch.Tensor]:
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    index = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in index])
    y = torch.stack([data[i+1:i+block_size+1] for i in index])
    x, y = x.to(device), y.to(device)
    return x, y

# %%
x, y = get_batch('train')
x.shape, y.shape
# Out:
# (torch.Size([128, 512]), torch.Size([128, 512]))

# %% [markdown]
# ### 4. Training

# %%
from typing import Dict

eval_iters = 200


@torch.no_grad()
def estimate_loss() -> Dict:
    output = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            x, y = get_batch(split)
            _, loss = model(x, y)
            losses[k] = loss.item()
        output[split] = losses.mean().item()
    model.train()
    return output

# %%
def save_checkpoint(
    model: GPTLanguageModel,
    optimizer: torch.optim.Optimizer,
    epoch: int,
    loss: float,
    file_path: str = "checkpoint.pth"
) -> None:
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss
    }
    torch.save(checkpoint, file_path)

# %%
import torch

if 'model' not in globals():
    from transformer.model import GPTLanguageModel

    block_size = 512
    n_embd = 128
    n_head = 8
    n_layer = 1
    dropout = 0.2
    batch_size = 128
    vocab_size = get_vocab_size(tokenizer)
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    model = GPTLanguageModel(
        vocab_size=vocab_size,
        block_size=block_size,
        n_embd=n_embd,
        n_head=n_head,
        n_layer=n_layer,
        dropout=dropout,
        device=device
    ).to(device)

max_iters = 1000
eval_interval = 10
learning_rate = 1e-4
save_interval = 100
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

train_losses = []
val_losses = []

for iteration in range(max_iters):
    if iteration % eval_interval == 0 or iteration == max_iters - 1:
        losses = estimate_loss()
        print(
            f"step {iteration}: "
            f"train loss {losses['train']:.4f}, "
            f"val loss {losses['val']:.4f}"
        )
        train_losses.append(losses['train'])
        val_losses.append(losses['val'])

    x_batch, y_batch = get_batch('train')
    logits, loss = model(x_batch, y_batch)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

    if iteration % save_interval == 0:
        save_checkpoint(
            model=model,
            optimizer=optimizer,
            epoch=iteration,
            loss=loss.item(),
            file_path=f"../output/pre_training/run_1/checkpoint_{iteration}.pth"
        )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 36
#      32 val_losses = []
#      33
#      34 for iteration in range(max_iters):
#      35     if iteration % eval_interval == 0 or iteration == max_iters - 1:
# ---> 36         losses = estimate_loss()
#      37         print(
#      38             f"step {iteration}: "
#      39             f"train loss {losses['train']:.4f}, "
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[9], line 14, in estimate_loss()
#      10     for split in ['train', 'val']:
#      11         losses = torch.zeros(eval_iters)
#      12         for k in range(eval_iters):
#      13             x, y = get_batch(split)
# ---> 14             _, loss = model(x, y)
#      15             losses[k] = loss.item()
#      16         output[split] = losses.mean().item()
#      17     model.train()
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File d:\Train_Your_Language_Model_Course-clean\notebooks\..\transformer\model.py:138, in GPTLanguageModel.forward(self, input_tokens, targets)
#     136 x = self.blocks(x)
#     137 x = self.final_layer_norm(x)
# --> 138 logits = self.final_linear_layer(x)
#     140 if targets is None:
#     141     loss = None
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Evaluation Step")
plt.ylim(0)
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Time")
plt.legend()
plt.grid()
plt.show()

# %%
input_tokens = tokenizer.encode("Salam labas")
input_tokens = torch.tensor(
    input_tokens, dtype=torch.long).unsqueeze(0).to(device)

model.eval()
with torch.no_grad():
    output = model.generate(input_tokens=input_tokens, max_new_tokens=50)

print(tokenizer.decode(output[0].tolist()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 9
#       5 model.eval()
#       6 with torch.no_grad():
#       7     output = model.generate(input_tokens=input_tokens, max_new_tokens=50)
#       8
# ----> 9 print(tokenizer.decode(output[0].tolist()))
#
# File d:\Train_Your_Language_Model_Course-clean\notebooks\..\minbpe\basic.py:55, in BasicTokenizer.decode(self, ids)
#      53 def decode(self, ids):
#      54     # given ids (list of integers), return Python string
# ---> 55     text_bytes = b"".join(self.vocab[idx] for idx in ids)
#      56     text = text_bytes.decode("utf-8", errors="replace")
#      57     return text
#
# File d:\Train_Your_Language_Model_Course-clean\notebooks\..\minbpe\basic.py:55, in <genexpr>(.0)
#      53 def decode(self, ids):
#      54     # given ids (list of integers), return Python string
# ---> 55     text_bytes = b"".join(self.vocab[idx] for idx in ids)
#      56     text = text_bytes.decode("utf-8", errors="replace")
#      57     return text
#
# KeyError: 1031
