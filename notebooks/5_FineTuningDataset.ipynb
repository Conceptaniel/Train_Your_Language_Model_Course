# %% [markdown]
# ## Read the file

# %%
from pathlib import Path

file_path = Path("../data/private/Direct Messages - Buncha retards [1411801796439183370].txt")
if not file_path.exists():
    raise FileNotFoundError(f"Could not find expected data file: {file_path}")

with file_path.open('r', encoding='utf-8') as f:
    lines = f.readlines()

len(lines)
# Out:
# 28015

# %% [markdown]
# ## Clean the conversation

# %%
import re

encryption_message = "Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more."
media_pattern = "{Embed}"
email_pattern = r'[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}'
url_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
edited_message = "<This message was edited>"
deleted_message = "You deleted this message"
null_message = "null"
created_group_message = "created group"
added_you_to_group_message = "added you"
tagging_pattern = r'@[\w]+'


filtered_lines = []
for line in lines:
    if (
            encryption_message not in line and
            deleted_message not in line and
            null_message != line.split(" ")[-1] and
            media_pattern not in line and
            created_group_message not in line and
            added_you_to_group_message not in line and
            not re.search(email_pattern, line) and
            not re.search(url_pattern, line)
    ):
        line = line.replace(edited_message, "").strip()
        line = re.sub(tagging_pattern, "", line).strip()
        filtered_lines.append(line)

pattern = r'(\d{2}/\d{2}/\d{4}, \d{2}:\d{2}) - (.*?): (.*?)(?=\n\d{2}/\d{2}/\d{4}, \d{2}:\d{2} -|$)'
content = '\n'.join(filtered_lines)
messages = re.findall(pattern, content, re.DOTALL)

lines_removed = len(lines) - len(filtered_lines)
print(f"Lines removed: {lines_removed}")
# Out:
# Lines removed: 862

# %% [markdown]
# ## Create the dataset

# %% [markdown]
# ### 1. Group messages by sender

# %% [markdown]
# If a conversation is structured as follows:
#
# ```
# User 1: Hey!
# User 1: How are you?
# User 2: I am fine
# User 2: And you?
# User 1: Good.
# ```
#
# We want to transform it into:
#
# ```
# User 1: Hey!\nHow are you?
# User 2: I am fine\nAnd you?
# User 1: Good
# ```

# %%
grouped_messages = []

for _, sender, message in messages:
    if grouped_messages and grouped_messages[-1]["sender"] == sender:
        grouped_messages[-1]["message"] += "\n" + message
    else:
        grouped_messages.append({
            "sender": sender,
            "message": message
        })

len(grouped_messages)
# Out:
# 13568

# %% [markdown]
# ### 2. Include special tokens

# %% [markdown]
# Each message follows this format:
# ```
# <|startoftext|>Sender<|separator|>Message<|endoftext|>
# ```

# %%
# Define special tokens
start_of_text_token = "<|startoftext|>"
end_of_text_token = "<|endoftext|>"
separator_token = "<|separator|>"

fine_tuning_data = []

for message in grouped_messages:
    sender = message["sender"]
    message_text = message["message"]
    input_sequence = f"{start_of_text_token}{sender}{separator_token}{message_text}{end_of_text_token}"
    fine_tuning_data.append(input_sequence)

len(fine_tuning_data)
# Out:
# 13568

# %% [markdown]
# ### 3. Save the data

# %%
import json
from pathlib import Path

save_path = Path("../output/fine_tuning/data/fine_tuning.json")
save_path.parent.mkdir(parents=True, exist_ok=True)

with save_path.open('w', encoding='utf-8') as f:
    json.dump(fine_tuning_data, f, ensure_ascii=False, indent=4)

save_path
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 import json
#       2
#       3 save_path = "../output/fine_tuning/data/fine_tuning.json"
# ----> 4 with open(save_path, 'w', encoding='utf-8') as f:
#       5     json.dump(fine_tuning_data, f, ensure_ascii=False, indent=4)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output/fine_tuning/data/fine_tuning.json'
