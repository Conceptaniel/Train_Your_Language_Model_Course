# %% [markdown]
# ## Load the tokenizer

# %%
import sys
sys.path.append('..')

# %%
from minbpe import BasicTokenizer

tokenizer = BasicTokenizer()
tokenizer.load(model_file="../output/tokenizer/my_tokenizer.model")


def get_vocab_size(tokenizer: BasicTokenizer) -> int:
    vocab = tokenizer.vocab
    special_tokens = tokenizer.special_tokens

    return len(vocab) + len(special_tokens)

# %% [markdown]
# ## Create the model

# %%
import torch
torch.manual_seed(3647)

# %%
from transformer.model import GPTLanguageModel

block_size = 256
n_embd = 512
n_head = 8
n_layer = 4
dropout = 0.2
batch_size = 64
vocab_size = get_vocab_size(tokenizer)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = GPTLanguageModel(
    vocab_size=vocab_size,
    block_size=block_size,
    n_embd=n_embd,
    n_head=n_head,
    n_layer=n_layer,
    dropout=dropout,
    device=device
).to(device)
model = getattr(model, "__wrapped__", model)  # Ensure the raw model object is used
# model = torch.compile(model)  # Disabled on Windows unless MSVC compiler is installed

print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')
# Out:
# 13.795338 M parameters

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### 1. Load the data

# %%
with open("../output/combined_text.txt", "r", encoding='utf-8') as f:
    text_sequence = f.read()

encoded_text_sequence = tokenizer.encode(text_sequence)
len(encoded_text_sequence)
# Out:
# 411925

# %% [markdown]
# ### 2. Split it into train and test

# %%
data = torch.tensor(encoded_text_sequence, dtype=torch.long)
split_index = int(0.9 * len(data))
train_data = data[:split_index]
val_data = data[split_index:]

# %% [markdown]
# ### 3. Data loader

# %%
from typing import Tuple
from torch.utils.data import Dataset, DataLoader


class TextDataset(Dataset):
    def __init__(self, data: torch.Tensor, block_size: int) -> None:
        if len(data) <= block_size:
            raise ValueError(
                f"The length of the data ({len(data)}) must be greater than the block_size ({block_size})."
            )

        self.data = data
        self.block_size = block_size

    def __len__(self) -> int:
        return len(self.data) - self.block_size

    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor]:
        x = self.data[index : index + self.block_size]
        y = self.data[index + 1 : index + self.block_size + 1]
        return x, y


def get_dataloaders(
    train_data: torch.Tensor,
    val_data: torch.Tensor,
    block_size: int,
    batch_size: int,
    device: torch.device,
) -> Tuple[DataLoader, DataLoader]:
    train_dataset = TextDataset(train_data.to(device), block_size)
    val_dataset = TextDataset(val_data.to(device), block_size)

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
    )

    return train_loader, val_loader

# %%
train_loader, val_loader = get_dataloaders(
    train_data=train_data,
    val_data=val_data,
    block_size=block_size,
    batch_size=batch_size,
    device=device,
)
x, y = next(iter(train_loader))
x.shape, y.shape
# Out:
# (torch.Size([64, 256]), torch.Size([64, 256]))

# %% [markdown]
# ### 4. Training

# %%
from typing import Dict


@torch.no_grad()
def estimate_loss(
    model: torch.nn.Module,
    train_loader: DataLoader,
    val_loader: DataLoader,
    eval_iters: int
) -> Dict[str, float]:
    output = {}
    model.eval()

    for split, loader in [('train', train_loader), ('val', val_loader)]:
        losses = torch.zeros(eval_iters)
        for i, (x, y) in enumerate(loader):
            if i >= eval_iters:
                break
            with torch.no_grad():
                _, loss = model(x, y)
            losses[i] = loss.item()
        output[split] = losses.mean().item()

    model.train()
    return output

# %%
def save_checkpoint(
    model: GPTLanguageModel,
    optimizer: torch.optim.Optimizer,
    epoch: int,
    loss: float,
    file_path: str = "checkpoint.pth"
) -> None:
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss
    }
    torch.save(checkpoint, file_path)

# %%
import torch
import torch.nn as nn
import os
os.makedirs("../output/pre_training/run_4", exist_ok=True)
max_iters = 50
eval_interval = 1
eval_iters = 50
learning_rate = 3e-4

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
train_loader, val_loader = get_dataloaders(
    train_data=train_data,
    val_data=val_data,
    block_size=block_size,
    batch_size=batch_size,
    device=device
)
model.train()
train_losses = []
val_losses = []

for iteration in range(max_iters):
    for batch_idx, (x_batch, y_batch) in enumerate(train_loader):
        # Evaluation
        if batch_idx % eval_interval == 0 or batch_idx == len(train_loader) - 1:
            losses = estimate_loss(
                model=model,
                train_loader=train_loader,
                val_loader=val_loader,
                eval_iters=min(eval_iters, len(val_loader))
            )
            train_losses.append(losses['train'])
            val_losses.append(losses['val'])

            print(
                f"iteration {iteration} / step {batch_idx}: "
                f"train loss {losses['train']:.4f}, "
                f"val loss {losses['val']:.4f}"
            )

        # Training step
        logits, loss = model(x_batch, y_batch)
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # Save checkpoint
    save_checkpoint(
        model=model,
        optimizer=optimizer,
        epoch=iteration,
        loss=loss.item(),
        file_path=f"../output/pre_training/run_4/checkpoint_{iteration}.pth"
    )
# Out:
# iteration 0 / step 0: train loss 4.8303, val loss 4.7976
# iteration 0 / step 1: train loss 5.0402, val loss 5.0015
# iteration 0 / step 2: train loss 4.9341, val loss 4.9175
# iteration 0 / step 3: train loss 4.8912, val loss 4.8635
# iteration 0 / step 4: train loss 4.8736, val loss 4.8194
# iteration 0 / step 5: train loss 4.8610, val loss 4.8014
# iteration 0 / step 6: train loss 4.8296, val loss 4.7966
# iteration 0 / step 7: train loss 4.8389, val loss 4.7861
# iteration 0 / step 8: train loss 4.8129, val loss 4.7714
# iteration 0 / step 9: train loss 4.8052, val loss 4.7603
# iteration 0 / step 10: train loss 4.7945, val loss 4.7531
# iteration 0 / step 11: train loss 4.7880, val loss 4.7465
# iteration 0 / step 12: train loss 4.7821, val loss 4.7406
# iteration 0 / step 13: train loss 4.7689, val loss 4.7326
# iteration 0 / step 14: train loss 4.7581, val loss 4.7270
# iteration 0 / step 15: train loss 4.7592, val loss 4.7203
# iteration 0 / step 16: train loss 4.7498, val loss 4.7146
# iteration 0 / step 17: train loss 4.7439, val loss 4.7088
# iteration 0 / step 18: train loss 4.7342, val loss 4.7029
# iteration 0 / step 19: train loss 4.7275, val loss 4.6971
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 26
#      22 for iteration in range(max_iters):
#      23     for batch_idx, (x_batch, y_batch) in enumerate(train_loader):
#      24         # Evaluation
#      25         if batch_idx % eval_interval == 0 or batch_idx == len(train_loader) - 1:
# ---> 26             losses = estimate_loss(
#      27                 model=model,
#      28                 train_loader=train_loader,
#      29                 val_loader=val_loader,
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[13], line 20, in estimate_loss(model, train_loader, val_loader, eval_iters)
#      16         for i, (x, y) in enumerate(loader):
#      17             if i >= eval_iters:
#      18                 break
#      19             with torch.no_grad():
# ---> 20                 _, loss = model(x, y)
#      21             losses[i] = loss.item()
#      22         output[split] = losses.mean().item()
#      23
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File d:\Train_Your_Language_Model_Course-clean\notebooks\..\transformer\model.py:136, in GPTLanguageModel.forward(self, input_tokens, targets)
#     133 positional_embedding = self.position_embedding_table(
#     134     torch.arange(T, device=self.device))
#     135 x = token_embedding + positional_embedding
# --> 136 x = self.blocks(x)
#     137 x = self.final_layer_norm(x)
#     138 logits = self.final_linear_layer(x)
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File d:\Train_Your_Language_Model_Course-clean\notebooks\..\transformer\model.py:87, in Block.forward(self, x)
#      86 def forward(self, x: torch.Tensor) -> torch.Tensor:
# ---> 87     x = x + self.self_attention(self.layer_norm_1(x))
#      88     x = x + self.feed_forward(self.layer_norm_2(x))
#      89     return x
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\normalization.py:217, in LayerNorm.forward(self, input)
#     216 def forward(self, input: Tensor) -> Tensor:
# --> 217     return F.layer_norm(
#     218         input, self.normalized_shape, self.weight, self.bias, self.eps
#     219     )
#
# File c:\Users\dglan\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\functional.py:2900, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2890 if has_torch_function_variadic(input, weight, bias):
#    2891     return handle_torch_function(
#    2892         layer_norm,
#    2893         (input, weight, bias),
#    (...)   2898         eps=eps,
#    2899     )
# -> 2900 return torch.layer_norm(
#    2901     input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2902 )
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses, label="Train Loss", marker='o')
plt.plot(val_losses, label="Validation Loss", marker='o')
plt.xlabel("Evaluation Step")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Time")
plt.legend()
plt.grid()
plt.show()

# %%
input_tokens = tokenizer.encode("vro")
input_tokens = torch.tensor(
    input_tokens, dtype=torch.long).unsqueeze(0).to(device)

model.eval()
with torch.no_grad():
    output = model.generate(input_tokens=input_tokens, max_new_tokens=100)

print(tokenizer.decode(output[0].tolist()))
# Out:
# vroll in Fesoon from haictickfor an what is that We is and detic like Eo Thame Its chat if If you out Oh Is When ting shirl how not like if aheem were vieed to spon? I canss u short inder max have more pretty Im gay which pintorithing first should i guy To can just do that pretty too much min bro should row
